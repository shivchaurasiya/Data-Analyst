# %% [markdown]
# # Data Cleaning Assessment – Student Copy
# ## Practical Exam | Data Cleaning with Pandas
#
# **Instructions:**
# 1. Read each section carefully and complete the missing code cells.
# 2. Perform data cleaning step-by-step without skipping validation steps.
# 3. Ensure the final cleaned DataFrame is assigned to `clean_df` and exported as `clean_student_data_80k.csv`.
#
# ---

# %% [markdown]
# ### Step 1: Import Libraries and Load Dataset
# - Load `messy_student_data_80k.csv` into a pandas DataFrame named `df`.
# - Inspect the first 10 rows and check the dataset shape.

# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv('messy_student_data_80k.csv')
print('Dataset Shape:', df.shape)
df.head(10)
# Out:
# Dataset Shape: (80000, 12)
#    Student ID       Full Name                Contact Email   Age   Gender  \
# 0  STU-770487  Vihaan Chauhan       pooja.rao802@yahoo.com  20.0     Male
# 1  STU-216739     Rohan Kumar  ishita.patel425@outlook.com  15.0     male
# 2  STU-126225     Karan Gupta     kabir.patel893@yahoo.com  21.0        M
# 3  STU-877572       Aarav Rao    aditya.patel192@gmail.com  21.0        F
# 4  STU-388389    Kavya Tiwari      pooja.rao69@example.com  19.0   Female
# 5  STU-356787   Rohan Chauhan   pooja.chauhan958@gmail.com  19.0      NaN
# 6  STU-334053   Karan Chauhan   rohan.mehta301@example.com  18.0      NaN
# 7  STU-246316     Kavya Kumar     aditya.jain838@gmail.com  23.0    other
# 8  STU-872246     Kabir Patel     ishita.kumar54@gmail.com  21.0  unknown
# 9  STU-207473    Rahul Tiwari      diya.yadav131@gmail.com  21.0     Male
#
#         City              Department Degree Course  Marks Percentage  \
# 0        NaN            data science         MTECH              50.0
# 1     Jaipur                     ece          B.Sc               NaN
# 2     MUMBAI            data science        m.tech              91.4
# 3  Bengaluru                      me           bca              45.0
# 4      Delhi        Computer Science         BTECH             105.0
# 5  Hyderabad  Information Technology        B.Tech               NaN
# 6  Bengaluru              Mechanical         btech              82.0
# 7    Gurgaon           Not Available           bca              82.0
# 8    Gurgaon           Not Available         MTECH              50.0
# 9     Mumbai                     ece           BCA             105.0
#
#   Annual Package Mobile Number Enrollment Date
# 0         600000    6225065004    invalid_date
# 1        1200000    6969175668             NaN
# 2         -50000    9999999999      2023-01-10
# 3         -50000    9829174369      2022-08-15
# 4       99999999    abc1234567      2024-02-20
# 5        1200000    7219981994      2024-02-20
# 6         350000    9620276080      2023-09-01
# 7        unknown    6801080019             NaN
# 8        unknown    8472707829      2023-01-10
# 9         800000    7834744247      2023-01-10

# %% [markdown]
# ### Step 2: Standardize Column Names
# Rename columns to snake_case:
# `student_id`, `student_name`, `email`, `age`, `gender`, `city`, `department`, `course`, `marks`, `annual_salary`, `phone`, `admission_date`

# %%
# TODO: Rename columns

# %% [markdown]
# ### Step 3: Handle Missing Values & Placeholders
# - Replace placeholders (`'NA'`, `'N/A'`, `'null'`, `'Not Available'`, `'unknown'`) with `np.nan`.
# - Impute categorical columns with `'Unknown'`.
# - Impute missing numeric values using column medians.

# %%
# TODO: Replace string placeholders with NaN
df.replace(['?', 'NA', 'N/A', 'na', 'n/a', ''], np.nan, inplace=True)   
df.info()

# TODO: Impute categorical & numeric missing values

# %% [markdown]
# ### Step 4: Text Cleaning & Category Standardization
# - Strip whitespaces.
# - Standardize: `bangalore` -> `bengaluru`, `gurgaon` -> `gurugram`.
# - Standardize departments (`computer science` -> `cse`, etc.).
# - Standardize degree courses (`btech`, `mtech`, `bca`, `bsc`).

# %%
# TODO: Clean and standardize text columns

# %% [markdown]
# ### Step 5: Remove Duplicates
# - Identify and drop duplicate rows.

# %%
# TODO: Count and drop duplicate rows

# %% [markdown]
# ### Step 6: Validate Numeric Boundaries & Outliers
# - `age`: 17 to 35
# - `marks`: 0 to 100
# - `annual_salary`: > 0 and < 10,000,000

# %%
# TODO: Fix invalid numeric ranges and fill with median

# %% [markdown]
# ### Step 7: Email & Phone Validation
# - Validate email pattern.
# - Clean phone numbers (10 digits starting with 6-9).

# %%
# TODO: Validate emails and clean mobile numbers

# %% [markdown]
# ### Step 8: Parse Dates & Export
# - Convert `admission_date` to datetime.
# - Export final cleaned DataFrame to `clean_student_data_80k.csv`.

# %%
clean_df = df.copy()
# clean_df.to_csv('clean_student_data_80k.csv', index=False)
clean_df.info()
